# %% [markdown]
# <a href="https://colab.research.google.com/github/Batatazim/Python/blob/master/Lista4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Disciplina: Probabilidade e Estatística
#Aluno: Daniel Alves Gonçalves Pires da Silva
#Lista 4

#Questão 1 

'''lados = int(input("Digite a quantidade de lados desejada: "))
medida = float(input("Digite a medida dos lados: "))
if lados == 3:
  area = medida ** 2 * 3 ** (1/2) / 4
  print("Três lados portanto é um Triângulo")
  print("A área é igual á:%.2f"%area,"cm")
elif lados == 4:
  area = medida ** 2
  print("Quatros lados portanto é um Quadrado")
  print("A área é igual á:%.2f"%area,"cm")
elif lados == 5:
  print("Cinco lados portanto é um Pentagono")'''


#Questão 2

'''lados = int(input("Digite a quantidade de lados desejada: "))
medida = float(input("Digite a medida dos lados: "))
if lados < 3:
  print("Não é um polígono")
if lados == 3:
  area = medida ** 2 * 3 ** (1/2) / 4
  print("Três lados portanto é um Triângulo")
  print("A área é igual á:%.2f"%area,"cm")
elif lados == 4:
  area = medida ** 2
  print("Quatros lados portanto é um Quadrado")
  print("A área é igual á:%.2f"%area,"cm")
elif lados == 5:
  print("Cinco lados portanto é um Pentagono")
elif lados > 5:
  print("Polígono não identificado")'''


#Questão 3

'''print("Digite três números")
n1 = int(input("Digite o primeiro número: "))
n2 = int(input("Digite o segundo número: "))
n3 = int(input("Digite o terceiro número: "))

maior = n1
if n2>n1 and n2>n3:
  maior = n2

if n3>n1 and n3>n2:
  maior= n3

print("O maior número é:",maior)'''


#Questão 4

'''print("Escolha as medidas de cada lado de um triângulo")
m1 = int(input("Medida 1: "))
m2 = int(input("Medida 2: "))
m3 = int(input("Medida 3: "))  

if m1 == m2 and m2 == m3:
  print("É um triângulo equilatero")

elif m1 == m2 or m2 == m3 or m1 == m3:
  print("É um triângulo isósceles")

else:
  print("É um triângulo escaleno")'''


#Questão 5

'''a1 = int(input("Digite o ângulo 1: "))
a2 = int(input("Digite o ângulo 2: "))
a3 = int(input("Digite o ângulo 3: "))

if a1 == 90 or a2 == 90 or a3 == 90:
  print("Triângulo retangulo")

elif a1 < 90 and a2 < 90 and a3 < 90:
  print("Triângulo acutângulo")

else:
  print("Triângulo obtusângulo")'''

#Questão 6

''''n = int(input("Digite um número: "))
list(range(n))'''


#Questão 7

'''n = int(input("Digite um número de 1 a 4: "))

if n > 4 or n < 1:
  print("Entrada inválida")
  print("Digite o número novamente")

elif n > 1 or n < 4:
  print("O número digitado foi:",n)'''


#Questão 8

'''maior = []
while True:
 n = int(input("Digite um número ou digite 0 para encerrar: "))
 if n == 0:
   break
 maior.append(n)
print("O maior numero foi:",max(maior))'''


#Questão 9

'''valor4 = int(input("Digite um número com quatro digitos: "))
n = str(valor4)
print("Unidade:{}".format(n[3]))
print("Dezena:{}".format(n[2]))
print("Centena:{}".format(n[1]))
print("Milhar:{}".format(n[0]))'''
